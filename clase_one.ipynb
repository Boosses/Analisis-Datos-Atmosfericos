# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv")


# Para traer una especifica df['CO']
# Para llamar a traer las variables que tenemos df.columns

# Calcular el CO
# Aplicaremo la formula, sumar todos los datos, dividir numero de datos entre 3071
#(df['CO'].sum())/3071

# Calcular la media
# df['CO'].mean()

# Calcular la mediana
# df['CO'].median()

# Resumen de 5 Numeros
# El resume de 5 num sirve para hacer un grafico de caja
#df['O3'].quantile([.25, .50, .75])
# sacar mean, min, 25%, 50%, 75%, max
#df['O3'].describe()

# Me interesa saber información puedo poner describe a todo mi data
# df.describe()

# Un valor atipico es una observación que es numericamente distante del resto de los datos
# Obtener una grafica de caja para el NO2, vert = false es para que la grafica sea horizontal
# plt.boxplot(df['PM10'], vert = False)
# plt.show()

# Traer dos columnas
# df[['PM10','PM25']]
# sns.boxplot(data=df[['PM10','PM25']])

# Traer de todas
# sns.boxplot(data=df)

# Dar las dimensiones y orientación
# plt.figure(figsize=(10,5), dpi=150)
# sns.boxplot(data=df, orient='h')

# Cuantos datos antipicos tiene el NOX
# (df['NOX']>40).sum()
#df['NOX'].describe()
# IQR = 46.739-26.938
# (df['NOX']>46.739 + 1.5*(IQR)).sum()

#En que fecha se registraron
# df[['NOX','fecha']] [df['NOX']>46.739 + 1.5*(IQR)]

# Graficas de los contaminantes
#fig, ax = plt.subplots()
#ax.plot(df['CO']);

# Serie temporal, de que  forma esta indexado del CO
df['fecha'] = pd.to_datetime(df['fecha'])
#Idf.info()
df=df.set_index('fecha')
fig, ax = plt.subplots(figsize=(10,5),dpi=100)
ax.plot(df['PM25']['2022-01-01':'2022-12-31'], color='orange', lw=0.6);
ax.tick_params(labelsize=14)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14})
ax.axhline(25,color='red', lw=2, linestyle='--')
plt.show()

#print('Datos de 2018/05/23-2020:')
#df['CO']['2018-05-23':'2020-11-03']

# Realizar la grafica de 2 contaminantes
